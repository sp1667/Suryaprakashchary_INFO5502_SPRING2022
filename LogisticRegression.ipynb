# %% [markdown]
# <a href="https://colab.research.google.com/github/sp1667/Suryaprakashchary_INFO5502_SPRING2022/blob/main/LogisticRegression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Logistic Regression Model

# %%
# Importing required libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import classification_report

# %%
# Reading the Wine quality dataset by using pandas
data = pd.read_csv("/content/winequality-red.csv")
data
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
data.columns
# Out:
# Index(['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
#        'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
#        'pH', 'sulphates', 'alcohol', 'quality'],
#       dtype='object')

# %%
# Printing number of null values in each column
print (data.isnull().sum().sum())
# Out:
# 0

# %%
# Plotting relationship between features by using seaborn library
sns.set_theme(style='whitegrid')
#Realtionship between Fixed Acidity and Quality
sns.scatterplot(x='fixed acidity', y='quality', data=data)
plt.show()

# %%
#Plotting relationship between Volatile Acidity and Quality
sns.scatterplot(x='volatile acidity', y='quality', data=data)
plt.show()

# %%
#Plotting relationship between Citric Acid and Quality
sns.scatterplot(x='citric acid', y='quality', data=data)
plt.show()

# %%
#Plotting relationship between Residual sugar and Quality
sns.scatterplot(x='residual sugar', y='quality', data=data)
plt.show()

# %%
#Plotting relationship between Chlorides and Quality
sns.scatterplot(x='chlorides', y='quality', data=data)
plt.show()

# %%
#Plotting relationship between Free Sulphur Dioxide and Quality
sns.scatterplot(x='free sulfur dioxide', y='quality', data=data)
plt.show()

# %%
#Plotting relationship between Total Sulphur Dioxide and Quality
sns.scatterplot(x='total sulfur dioxide', y='quality', data=data)
plt.show()

# %%
#Plotting relationship between Density and Quality
sns.scatterplot(x='density', y='quality', data=data)
plt.show()

# %%
#Plotting relationship between pH and Quality
sns.scatterplot(x='pH', y='quality', data=data)
plt.show()

# %%
#Plotting relationship between Sulphates and Quality
sns.scatterplot(x='sulphates', y='quality', data=data)
plt.show()

# %%
#Plotting relationship between Alcohol and Quality
sns.scatterplot(x='alcohol', y='quality', data=data)
plt.show()

# %%
# Seperating the dependent variable column from dataset and assigning new dataframe
x = data[['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
       'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
       'pH', 'sulphates', 'alcohol']]
y = data['quality']

# %%
# Importing train_test_split from sklearn.model_selection package
from sklearn.model_selection import train_test_split
# Splitting the dataset into the Training set and Test set
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.2)

# %%
# Importing LogisticRegression from sklearn.linear_model
from sklearn.linear_model import LogisticRegression
# Building the model
logreg = LogisticRegression(max_iter=7197)
# Fitting the model
logreg.fit(X_train, y_train)
# Out:
# LogisticRegression(max_iter=7197)

# %%
print(logreg.score(X_test, y_test))
# Out:
# 0.575

# %%
# Predicting the target values for training data with logistic reression model
y_pred_Log = logreg.predict(X_test)
y_pred_Log
# Out:
# array([5, 5, 6, 5, 5, 6, 5, 5, 7, 5, 6, 5, 6, 5, 5, 7, 5, 6, 5, 6, 5, 5,
#        5, 6, 6, 6, 5, 6, 5, 5, 6, 6, 5, 6, 7, 7, 6, 5, 5, 5, 5, 5, 5, 6,
#        6, 6, 5, 5, 5, 6, 6, 5, 5, 6, 6, 5, 5, 7, 5, 7, 6, 5, 5, 5, 5, 6,
#        6, 6, 5, 5, 6, 5, 7, 6, 5, 6, 6, 5, 6, 6, 6, 5, 6, 5, 5, 5, 5, 5,
#        6, 5, 5, 6, 6, 5, 6, 6, 6, 5, 5, 5, 5, 6, 5, 6, 6, 6, 6, 5, 5, 6,
#        5, 5, 6, 5, 5, 6, 5, 5, 6, 6, 5, 6, 5, 6, 6, 5, 6, 5, 5, 5, 6, 5,
#        5, 5, 5, 6, 5, 5, 6, 5, 7, 5, 6, 6, 5, 6, 6, 5, 6, 5, 6, 5, 5, 6,
#        6, 5, 5, 5, 5, 6, 6, 5, 5, 6, 5, 6, 5, 5, 5, 5, 5, 5, 6, 5, 5, 5,
#        5, 6, 5, 6, 6, 6, 6, 5, 5, 6, 5, 5, 6, 5, 6, 5, 6, 5, 5, 6, 6, 5,
#        5, 5, 5, 6, 6, 7, 5, 5, 6, 6, 7, 5, 6, 6, 6, 6, 6, 5, 5, 5, 5, 6,
#        5, 6, 6, 6, 5, 6, 5, 5, 5, 5, 6, 6, 5, 5, 6, 5, 6, 6, 6, 5, 5, 5,
#        5, 7, 5, 5, 6, 5, 6, 6, 5, 6, 5, 5, 6, 5, 5, 5, 6, 6, 5, 6, 6, 5,
#        6, 5, 6, 5, 5, 5, 5, 6, 5, 7, 6, 5, 7, 7, 5, 6, 7, 6, 5, 5, 5, 6,
# ...

# %%
# Displaying correlation matrix(heatmap) by using seaborn
np.random.seed(123)
sns.set_theme()
corr=data.corr()
plt.figure(figsize=(12,6))
sns.heatmap(corr,xticklabels=corr.columns,yticklabels=corr.columns,annot=True,vmin=-1,vmax=1,cmap='YlOrBr')

# %%
# Finding accuracy
from sklearn.metrics import accuracy_score
print('Accuracy of Logestic Regression:', accuracy_score(y_pred_Log, y_test))
# Out:
# Accuracy of Logestic Regression: 0.575

# %%
# Confusion matrix for predicted and actual target values
from sklearn.metrics import confusion_matrix
conf_matrix = confusion_matrix(y_test, y_pred_Log)
conf_matrix
# Out:
# array([[  0,   0,   4,   0,   0],
#        [  0,   0,   9,   5,   0],
#        [  0,   0, 102,  29,   1],
#        [  0,   0,  56,  73,   8],
#        [  0,   0,   2,  22,   9]])

# %%
# Plotting heatmap for the confusion matrix by using seaborn
ho = sns.heatmap(conf_matrix, annot=True, cmap='YlOrBr')
ho.set_xlabel('\nPredicted Values')
ho.set_ylabel('Actual Values ');
plt.figure(figsize=(12,6))
plt.show()

# %%
print(classification_report(y_test, y_pred_Log))
# Out:
#               precision    recall  f1-score   support
#
#            3       0.00      0.00      0.00         4
#            4       0.00      0.00      0.00        14
#            5       0.59      0.77      0.67       132
#            6       0.57      0.53      0.55       137
#            7       0.50      0.27      0.35        33
#
#     accuracy                           0.57       320
#    macro avg       0.33      0.32      0.31       320
# weighted avg       0.54      0.57      0.55       320
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# ...
